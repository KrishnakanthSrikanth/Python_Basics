# %%
import pandas as pd

# %%
#Reading csv file
index = pd.read_csv("D:\hp 15-bs amd 160622\e\Coding_Practice\index.csv")

# %%
index.head()
# Out:
#    A  B  C   D  E  F      G      H       I    J  K  L
# 0  C  A  8   0  S  0   COIL  0.700   610.0    0  0  3
# 1  C  R  0   0  S  0   COIL  3.200   610.0    0  0  3
# 2  C  R  0   0  S  0  SHEET  0.700  1300.0  762  0  3
# 3  C  A  0  60  ?  0   COIL  2.801   385.1    0  0  3
# 4  C  A  0  60  ?  0  SHEET  0.801   255.0  269  0  3

# %%
#Access third column of the dataframe
index["D"]
# Out:
# 0       0
# 1       0
# 2       0
# 3      60
# 4      60
#        ..
# 252    60
# 253     0
# 254    50
# 255     0
# 256     0
# Name: D, Length: 257, dtype: int64

# %%
#Access last two columns of dataframe
index.iloc[:,-2:]
# Out:
#      K  L
# 0    0  3
# 1    0  3
# 2    0  3
# 3    0  3
# 4    0  3
# ..  .. ..
# 252  0  3
# 253  0  3
# 254  0  3
# 255  0  3
# 256  0  3
#
# [257 rows x 2 columns]

# %%
#Access the last 10 rows and first 2 columns of dataframe
index.iloc[-10:,:2]
# Out:
#      A  B
# 247  C  R
# 248  C  A
# 249  C  A
# 250  C  R
# 251  C  A
# 252  C  A
# 253  C  R
# 254  C  A
# 255  C  K
# 256  C  R
